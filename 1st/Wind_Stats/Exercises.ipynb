# %% [markdown]
# # Wind Statistics

# %% [markdown]
# ### Introduction:
#
# The data have been modified to contain some missing values, identified by NaN.
# Using pandas should make this exercise
# easier, in particular for the bonus question.
#
# You should be able to perform all of these operations without using
# a for loop or other looping construct.
#
#
# 1. The data in 'wind.data' has the following format:

# %%
"""
Yr Mo Dy   RPT   VAL   ROS   KIL   SHA   BIR   DUB   CLA   MUL   CLO   BEL   MAL
61  1  1 15.04 14.96 13.17  9.29   NaN  9.87 13.67 10.25 10.83 12.58 18.50 15.04
61  1  2 14.71   NaN 10.83  6.50 12.62  7.67 11.50 10.04  9.79  9.67 17.54 13.83
61  1  3 18.50 16.88 12.33 10.13 11.17  6.17 11.25   NaN  8.50  7.67 12.75 12.71
"""
# Out:
# '\nYr Mo Dy   RPT   VAL   ROS   KIL   SHA   BIR   DUB   CLA   MUL   CLO   BEL   MAL\n61  1  1 15.04 14.96 13.17  9.29   NaN  9.87 13.67 10.25 10.83 12.58 18.50 15.04\n61  1  2 14.71   NaN 10.83  6.50 12.62  7.67 11.50 10.04  9.79  9.67 17.54 13.83\n61  1  3 18.50 16.88 12.33 10.13 11.17  6.17 11.25   NaN  8.50  7.67 12.75 12.71\n'

# %% [markdown]
#    The first three columns are year, month and day.  The
#    remaining 12 columns are average windspeeds in knots at 12
#    locations in Ireland on that day.
#
#    More information about the dataset go [here](wind.desc).

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/06_Stats/Wind_Stats/wind.data)

# %% [markdown]
# ### Step 3. Assign it to a variable called data and replace the first 3 columns by a proper datetime index.

# %%
data = pd.read_csv(r'https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/06_Stats/Wind_Stats/wind.data'
        ,sep=' ')
data
# Out:
#       Yr    Mo    Dy  Unnamed: 3  Unnamed: 4    RPT  Unnamed: 6  Unnamed: 7  \
# 0     61   NaN   1.0         NaN        1.00  15.04       14.96       13.17
# 1     61   NaN   1.0         NaN        2.00  14.71         NaN         NaN
# 2     61   NaN   1.0         NaN        3.00  18.50       16.88       12.33
# 3     61   NaN   1.0         NaN        4.00  10.58         NaN        6.63
# 4     61   NaN   1.0         NaN        5.00  13.33       13.25       11.42
# ...   ..   ...   ...         ...         ...    ...         ...         ...
# 6569  78  12.0  27.0       17.58       16.96  17.62         NaN        8.08
# 6570  78  12.0  28.0       13.21         NaN   5.46       13.46         NaN
# 6571  78  12.0  29.0       14.00       10.29  14.42         NaN        8.71
# 6572  78  12.0  30.0       18.50       14.04  21.29         NaN        9.13
# 6573  78  12.0  31.0       20.33       17.41  27.29         NaN        9.59
#
#         VAL  Unnamed: 9  ...  MUL  Unnamed: 30  Unnamed: 31  CLO  Unnamed: 33  \
# 0       NaN        9.29  ...  NaN          NaN          NaN  NaN          NaN
# 1       NaN       10.83  ...  NaN          NaN          NaN  NaN          NaN
# 2     10.13       11.17  ...  NaN          NaN          NaN  NaN          NaN
# 3     11.75         NaN  ...  NaN          NaN          NaN  NaN          NaN
# 4       NaN        6.17  ...  NaN          NaN          NaN  NaN          NaN
# ...     ...         ...  ...  ...          ...          ...  ...          ...
# 6569  13.21       11.67  ...  NaN          NaN          NaN  NaN          NaN
# 6570   5.00         NaN  ...  NaN          NaN          NaN  NaN          NaN
# 6571    NaN        9.71  ...  NaN          NaN          NaN  NaN          NaN
# 6572  12.75         NaN  ...  NaN          NaN          NaN  NaN          NaN
# 6573  12.08       10.13  ...  NaN          NaN          NaN  NaN          NaN
#
#       Unnamed: 34  BEL  Unnamed: 36  Unnamed: 37  MAL
# 0             NaN  NaN          NaN          NaN  NaN
# 1             NaN  NaN          NaN          NaN  NaN
# 2             NaN  NaN          NaN          NaN  NaN
# 3             NaN  NaN          NaN          NaN  NaN
# 4             NaN  NaN          NaN          NaN  NaN
# ...           ...  ...          ...          ...  ...
# 6569          NaN  NaN          NaN          NaN  NaN
# 6570          NaN  NaN          NaN          NaN  NaN
# 6571          NaN  NaN          NaN          NaN  NaN
# 6572          NaN  NaN          NaN          NaN  NaN
# 6573          NaN  NaN          NaN          NaN  NaN
#
# [6574 rows x 39 columns]

# %%
data.shape
# Out:
# (6574, 39)

# %%
data.head(30)
# Out:
#     Yr  Mo   Dy  Unnamed: 3  Unnamed: 4    RPT  Unnamed: 6  Unnamed: 7    VAL  \
# 0   61 NaN  1.0         NaN        1.00  15.04       14.96       13.17    NaN
# 1   61 NaN  1.0         NaN        2.00  14.71         NaN         NaN    NaN
# 2   61 NaN  1.0         NaN        3.00  18.50       16.88       12.33  10.13
# 3   61 NaN  1.0         NaN        4.00  10.58         NaN        6.63  11.75
# 4   61 NaN  1.0         NaN        5.00  13.33       13.25       11.42    NaN
# 5   61 NaN  1.0         NaN        6.00  13.21         NaN        8.12    NaN
# 6   61 NaN  1.0         NaN        7.00  13.50       14.29         NaN   9.50
# 7   61 NaN  1.0         NaN        8.00  10.96         NaN        9.75    NaN
# 8   61 NaN  1.0         NaN        9.00  12.58       10.83       10.00    NaN
# 9   61 NaN  1.0        10.0       13.37  11.12       19.50         NaN   8.33
# 10  61 NaN  1.0        11.0       10.58    NaN        9.87         NaN   8.42
# 11  61 NaN  1.0        12.0       19.75  12.08       18.50       10.54  10.29
# 12  61 NaN  1.0        13.0         NaN   9.92         NaN        3.54    NaN
# 13  61 NaN  1.0        14.0         NaN   9.04         NaN        5.66    NaN
# 14  61 NaN  1.0        15.0       12.04    NaN        9.67       11.75    NaN
# 15  61 NaN  1.0        16.0       16.42  11.25       15.67         NaN   4.71
# 16  61 NaN  1.0        17.0       17.75  14.37       17.33       10.13  13.96
# 17  61 NaN  1.0        18.0       19.83  12.04       20.79       18.54    NaN
# 18  61 NaN  1.0        19.0         NaN   4.92         NaN        3.42    NaN
# 19  61 NaN  1.0        20.0         NaN   9.59       11.83         NaN   7.96
# 20  61 NaN  1.0        21.0       14.33  10.25       11.92         NaN   6.13
# 21  61 NaN  1.0        22.0         NaN   9.59         NaN        5.88    NaN
# 22  61 NaN  1.0        23.0       16.54    NaN        9.96       18.54  10.46
# 23  61 NaN  1.0        24.0       25.04  14.83       25.84       15.67  21.46
# 24  61 NaN  1.0        25.0       13.62  11.17       12.67         NaN   6.04
# 25  61 NaN  1.0        26.0       24.37  18.79       17.50       14.25  18.91
# 26  61 NaN  1.0        27.0       22.04  20.79       17.41       16.21  19.04
# 27  61 NaN  1.0        28.0       17.67  13.54       13.33         NaN   8.87
# 28  61 NaN  1.0        29.0         NaN    NaN         NaN       23.91  22.29
# 29  61 NaN  1.0        30.0       12.21  11.42       10.92         NaN   7.92
#
#     Unnamed: 9  ...  MUL  Unnamed: 30  Unnamed: 31  CLO  Unnamed: 33  \
# 0         9.29  ...  NaN          NaN          NaN  NaN          NaN
# 1        10.83  ...  NaN          NaN          NaN  NaN          NaN
# 2        11.17  ...  NaN          NaN          NaN  NaN          NaN
# 3          NaN  ...  NaN          NaN          NaN  NaN          NaN
# 4         6.17  ...  NaN          NaN          NaN  NaN          NaN
# 5         9.96  ...  NaN          NaN          NaN  NaN          NaN
# 6          NaN  ...  NaN          NaN          NaN  NaN          NaN
# 7         7.62  ...  NaN          NaN          NaN  NaN          NaN
# 8         4.75  ...  NaN          NaN          NaN  NaN          NaN
# 9          NaN  ...  NaN          NaN          NaN  NaN          NaN
# 10         NaN  ...  NaN          NaN          NaN  NaN          NaN
# 11         NaN  ...  NaN          NaN          NaN  NaN          NaN
# 12        8.46  ...  NaN          NaN          NaN  NaN          NaN
# 13        7.08  ...  NaN          NaN          NaN  NaN          NaN
# 14        2.37  ...  NaN          NaN          NaN  NaN          NaN
# 15       11.34  ...  NaN          NaN          NaN  NaN          NaN
# 16       13.37  ...  NaN          NaN          NaN  NaN          NaN
# 17         NaN  ...  NaN          NaN          NaN  NaN          NaN
# 18        7.29  ...  NaN          NaN          NaN  NaN          NaN
# 19         NaN  ...  NaN          NaN          NaN  NaN          NaN
# 20       10.04  ...  NaN          NaN          NaN  NaN          NaN
# 21        9.92  ...  NaN          NaN          NaN  NaN          NaN
# 22       13.50  ...  NaN          NaN          NaN  NaN          NaN
# 23       18.58  ...  NaN          NaN          NaN  NaN          NaN
# 24       10.00  ...  NaN          NaN          NaN  NaN          NaN
# 25       15.67  ...  NaN          NaN          NaN  NaN          NaN
# 26       16.13  ...  NaN          NaN          NaN  NaN          NaN
# 27       15.04  ...  NaN          NaN          NaN  NaN          NaN
# 28       17.54  ...  NaN          NaN          NaN  NaN          NaN
# 29       13.08  ...  NaN          NaN          NaN  NaN          NaN
#
#     Unnamed: 34  BEL  Unnamed: 36  Unnamed: 37  MAL
# 0           NaN  NaN          NaN          NaN  NaN
# 1           NaN  NaN          NaN          NaN  NaN
# 2           NaN  NaN          NaN          NaN  NaN
# 3           NaN  NaN          NaN          NaN  NaN
# 4           NaN  NaN          NaN          NaN  NaN
# 5           NaN  NaN          NaN          NaN  NaN
# 6           NaN  NaN          NaN          NaN  NaN
# 7           NaN  NaN          NaN          NaN  NaN
# 8           NaN  NaN          NaN          NaN  NaN
# 9           NaN  NaN          NaN          NaN  NaN
# 10          NaN  NaN          NaN          NaN  NaN
# 11          NaN  NaN          NaN          NaN  NaN
# 12          NaN  NaN          NaN          NaN  NaN
# 13          NaN  NaN          NaN          NaN  NaN
# 14          NaN  NaN          NaN          NaN  NaN
# 15          NaN  NaN          NaN          NaN  NaN
# 16          NaN  NaN          NaN          NaN  NaN
# 17          NaN  NaN          NaN          NaN  NaN
# 18          NaN  NaN          NaN          NaN  NaN
# 19          NaN  NaN          NaN          NaN  NaN
# 20          NaN  NaN          NaN          NaN  NaN
# 21          NaN  NaN          NaN          NaN  NaN
# 22          NaN  NaN          NaN          NaN  NaN
# 23          NaN  NaN          NaN          NaN  NaN
# 24          NaN  NaN          NaN          NaN  NaN
# 25          NaN  NaN          NaN          NaN  NaN
# 26          NaN  NaN          NaN          NaN  NaN
# 27          NaN  NaN          NaN          NaN  NaN
# 28          NaN  NaN          NaN          NaN  NaN
# 29          NaN  NaN          NaN          NaN  NaN
#
# [30 rows x 39 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6574 entries, 0 to 6573
# Data columns (total 39 columns):
# Yr             6574 non-null int64
# Mo             1656 non-null float64
# Dy             6088 non-null float64
# Unnamed: 3     4743 non-null float64
# Unnamed: 4     4907 non-null float64
# RPT            4949 non-null float64
# Unnamed: 6     4318 non-null float64
# Unnamed: 7     4096 non-null float64
# VAL            4142 non-null float64
# Unnamed: 9     4473 non-null float64
# Unnamed: 10    3999 non-null float64
# ROS            4422 non-null float64
# Unnamed: 12    4181 non-null float64
# Unnamed: 13    4431 non-null float64
# KIL            4243 non-null float64
# Unnamed: 15    4353 non-null float64
# Unnamed: 16    3589 non-null float64
# SHA            3370 non-null float64
# Unnamed: 18    2887 non-null float64
# Unnamed: 19    2842 non-null float64
# BIR            2509 non-null float64
# Unnamed: 21    2496 non-null float64
# Unnamed: 22    2112 non-null float64
# DUB            2158 non-null float64
# Unnamed: 24    1757 non-null float64
# Unnamed: 25    1542 non-null float64
# CLA            984 non-null float64
# Unnamed: 27    611 non-null float64
# Unnamed: 28    146 non-null float64
# MUL            0 non-null float64
# Unnamed: 30    1 non-null float64
# Unnamed: 31    0 non-null float64
# CLO            0 non-null float64
# Unnamed: 33    0 non-null float64
# Unnamed: 34    0 non-null float64
# BEL            0 non-null float64
# Unnamed: 36    0 non-null float64
# Unnamed: 37    0 non-null float64
# MAL            0 non-null float64
# dtypes: float64(38), int64(1)
# memory usage: 2.0 MB

# %%
import missingno as msno

# NaN 값의 퍼센티지
for t in [data]:
    print()
    print()
    for col in t.columns:
        msg='column: {:>10}\t Percent of NaN value: {:.2f}%'\
        .format(col,(t[col].isnull().sum()/t[col].shape[0])*100)
        print(msg)

# 시각화 1
msno.matrix(data,figsize=(8,10),color=(0.8,0.5,0.2) )
# Out:
# column:         Yr	 Percent of NaN value: 0.00%
# column:         Mo	 Percent of NaN value: 74.81%
# column:         Dy	 Percent of NaN value: 7.39%
# column: Unnamed: 3	 Percent of NaN value: 27.85%
# column: Unnamed: 4	 Percent of NaN value: 25.36%
# column:        RPT	 Percent of NaN value: 24.72%
# column: Unnamed: 6	 Percent of NaN value: 34.32%
# column: Unnamed: 7	 Percent of NaN value: 37.69%
# column:        VAL	 Percent of NaN value: 36.99%
# column: Unnamed: 9	 Percent of NaN value: 31.96%
# column: Unnamed: 10	 Percent of NaN value: 39.17%
# column:        ROS	 Percent of NaN value: 32.74%
# column: Unnamed: 12	 Percent of NaN value: 36.40%
# column: Unnamed: 13	 Percent of NaN value: 32.60%
# column:        KIL	 Percent of NaN value: 35.46%
# column: Unnamed: 15	 Percent of NaN value: 33.78%
# column: Unnamed: 16	 Percent of NaN value: 45.41%
# column:        SHA	 Percent of NaN value: 48.74%
# column: Unnamed: 18	 Percent of NaN value: 56.08%
# column: Unnamed: 19	 Percent of NaN value: 56.77%
# column:        BIR	 Percent of NaN value: 61.83%
# column: Unnamed: 21	 Percent of NaN value: 62.03%
# column: Unnamed: 22	 Percent of NaN value: 67.87%
# column:        DUB	 Percent of NaN value: 67.17%
# column: Unnamed: 24	 Percent of NaN value: 73.27%
# column: Unnamed: 25	 Percent of NaN value: 76.54%
# column:        CLA	 Percent of NaN value: 85.03%
# column: Unnamed: 27	 Percent of NaN value: 90.71%
# column: Unnamed: 28	 Percent of NaN value: 97.78%
# column:        MUL	 Percent of NaN value: 100.00%
# column: Unnamed: 30	 Percent of NaN value: 99.98%
# column: Unnamed: 31	 Percent of NaN value: 100.00%
# column:        CLO	 Percent of NaN value: 100.00%
# column: Unnamed: 33	 Percent of NaN value: 100.00%
# column: Unnamed: 34	 Percent of NaN value: 100.00%
# column:        BEL	 Percent of NaN value: 100.00%
# column: Unnamed: 36	 Percent of NaN value: 100.00%
# column: Unnamed: 37	 Percent of NaN value: 100.00%
# column:        MAL	 Percent of NaN value: 100.00%

# %%
msno.bar(data,(8,8),color=(0.8,0.5,0.2))

# %%
data.head()
# Out:
#    Yr  Mo   Dy  Unnamed: 3  Unnamed: 4    RPT  Unnamed: 6  Unnamed: 7    VAL  \
# 0  61 NaN  1.0         NaN         1.0  15.04       14.96       13.17    NaN
# 1  61 NaN  1.0         NaN         2.0  14.71         NaN         NaN    NaN
# 2  61 NaN  1.0         NaN         3.0  18.50       16.88       12.33  10.13
# 3  61 NaN  1.0         NaN         4.0  10.58         NaN        6.63  11.75
# 4  61 NaN  1.0         NaN         5.0  13.33       13.25       11.42    NaN
#
#    Unnamed: 9  ...  MUL  Unnamed: 30  Unnamed: 31  CLO  Unnamed: 33  \
# 0        9.29  ...  NaN          NaN          NaN  NaN          NaN
# 1       10.83  ...  NaN          NaN          NaN  NaN          NaN
# 2       11.17  ...  NaN          NaN          NaN  NaN          NaN
# 3         NaN  ...  NaN          NaN          NaN  NaN          NaN
# 4        6.17  ...  NaN          NaN          NaN  NaN          NaN
#
#    Unnamed: 34  BEL  Unnamed: 36  Unnamed: 37  MAL
# 0          NaN  NaN          NaN          NaN  NaN
# 1          NaN  NaN          NaN          NaN  NaN
# 2          NaN  NaN          NaN          NaN  NaN
# 3          NaN  NaN          NaN          NaN  NaN
# 4          NaN  NaN          NaN          NaN  NaN
#
# [5 rows x 39 columns]

# %%
data.iloc[:,:3]
# Out:
#       Yr    Mo    Dy
# 0     61   NaN   1.0
# 1     61   NaN   1.0
# 2     61   NaN   1.0
# 3     61   NaN   1.0
# 4     61   NaN   1.0
# ...   ..   ...   ...
# 6569  78  12.0  27.0
# 6570  78  12.0  28.0
# 6571  78  12.0  29.0
# 6572  78  12.0  30.0
# 6573  78  12.0  31.0
#
# [6574 rows x 3 columns]

# %%
data.to_timestamp

# %%
################ 들여올때 연도로 바꾸면 됨
data = pd.read_csv(r'https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/06_Stats/Wind_Stats/wind.data'
        ,sep='\s+',parse_dates=[[0,1,2]])
data
# Out:
#        Yr_Mo_Dy    RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA  \
# 0    2061-01-01  15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25
# 1    2061-01-02  14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04
# 2    2061-01-03  18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN
# 3    2061-01-04  10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79
# 4    2061-01-05  13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54
# ...         ...    ...    ...    ...    ...    ...    ...    ...    ...
# 6569 1978-12-27  17.58  16.96  17.62   8.08  13.21  11.67  14.46  15.59
# 6570 1978-12-28  13.21   5.46  13.46   5.00   8.12   9.42  14.33  16.25
# 6571 1978-12-29  14.00  10.29  14.42   8.71   9.71  10.54  19.17  12.46
# 6572 1978-12-30  18.50  14.04  21.29   9.13  12.75   9.71  18.08  12.87
# 6573 1978-12-31  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63
#
#         MUL    CLO    BEL    MAL
# 0     10.83  12.58  18.50  15.04
# 1      9.79   9.67  17.54  13.83
# 2      8.50   7.67  12.75  12.71
# 3      5.83   5.88   5.46  10.88
# 4     10.92  10.34  12.92  11.83
# ...     ...    ...    ...    ...
# 6569  14.04  14.00  17.21  40.08
# 6570  15.25  18.05  21.79  41.46
# 6571  14.50  16.42  18.88  29.58
# 6572  12.46  12.12  14.67  28.79
# 6573  11.58  11.38  12.08  22.08
#
# [6574 rows x 13 columns]

# %%
import missingno as msno

# NaN 값의 퍼센티지
for t in [data]:
    print()
    print()
    for col in t.columns:
        msg='column: {:>10}\t Percent of NaN value: {:.2f}%'\
        .format(col,(t[col].isnull().sum()/t[col].shape[0])*100)
        print(msg)
# Out:
# column:   Yr_Mo_Dy	 Percent of NaN value: 0.00%
# column:        RPT	 Percent of NaN value: 0.09%
# column:        VAL	 Percent of NaN value: 0.05%
# column:        ROS	 Percent of NaN value: 0.03%
# column:        KIL	 Percent of NaN value: 0.08%
# column:        SHA	 Percent of NaN value: 0.03%
# column:        BIR	 Percent of NaN value: 0.00%
# column:        DUB	 Percent of NaN value: 0.05%
# column:        CLA	 Percent of NaN value: 0.03%
# column:        MUL	 Percent of NaN value: 0.05%
# column:        CLO	 Percent of NaN value: 0.02%
# column:        BEL	 Percent of NaN value: 0.00%
# column:        MAL	 Percent of NaN value: 0.06%

# %%
t=data.Yr_Mo_Dy.iloc[0]

# %%
import datetime
def fix_year(x):
    year = x.year-100 if x.year>1980 else x.year
    return datetime.date(year,x.month,x.day)
data.Yr_Mo_Dy = data.Yr_Mo_Dy.apply(fix_year)
data
# Out:
#         Yr_Mo_Dy    RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA  \
# 0     1961-01-01  15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25
# 1     1961-01-02  14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04
# 2     1961-01-03  18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN
# 3     1961-01-04  10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79
# 4     1961-01-05  13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54
# ...          ...    ...    ...    ...    ...    ...    ...    ...    ...
# 6569  1978-12-27  17.58  16.96  17.62   8.08  13.21  11.67  14.46  15.59
# 6570  1978-12-28  13.21   5.46  13.46   5.00   8.12   9.42  14.33  16.25
# 6571  1978-12-29  14.00  10.29  14.42   8.71   9.71  10.54  19.17  12.46
# 6572  1978-12-30  18.50  14.04  21.29   9.13  12.75   9.71  18.08  12.87
# 6573  1978-12-31  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63
#
#         MUL    CLO    BEL    MAL
# 0     10.83  12.58  18.50  15.04
# 1      9.79   9.67  17.54  13.83
# 2      8.50   7.67  12.75  12.71
# 3      5.83   5.88   5.46  10.88
# 4     10.92  10.34  12.92  11.83
# ...     ...    ...    ...    ...
# 6569  14.04  14.00  17.21  40.08
# 6570  15.25  18.05  21.79  41.46
# 6571  14.50  16.42  18.88  29.58
# 6572  12.46  12.12  14.67  28.79
# 6573  11.58  11.38  12.08  22.08
#
# [6574 rows x 13 columns]

# %% [markdown]
# ### Step 4. Year 2061? Do we really have data from this year? Create a function to fix it and apply it.

# %%
import datetime
def fix_year(x):
    year = x.year-100 if x.year>1980 else x.year
    return datetime.date(year,x.month,x.day)
data.Yr_Mo_Dy = data.Yr_Mo_Dy.apply(fix_year)
data
# Out:
#         Yr_Mo_Dy    RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA  \
# 0     1961-01-01  15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25
# 1     1961-01-02  14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04
# 2     1961-01-03  18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN
# 3     1961-01-04  10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79
# 4     1961-01-05  13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54
# ...          ...    ...    ...    ...    ...    ...    ...    ...    ...
# 6569  1978-12-27  17.58  16.96  17.62   8.08  13.21  11.67  14.46  15.59
# 6570  1978-12-28  13.21   5.46  13.46   5.00   8.12   9.42  14.33  16.25
# 6571  1978-12-29  14.00  10.29  14.42   8.71   9.71  10.54  19.17  12.46
# 6572  1978-12-30  18.50  14.04  21.29   9.13  12.75   9.71  18.08  12.87
# 6573  1978-12-31  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63
#
#         MUL    CLO    BEL    MAL
# 0     10.83  12.58  18.50  15.04
# 1      9.79   9.67  17.54  13.83
# 2      8.50   7.67  12.75  12.71
# 3      5.83   5.88   5.46  10.88
# 4     10.92  10.34  12.92  11.83
# ...     ...    ...    ...    ...
# 6569  14.04  14.00  17.21  40.08
# 6570  15.25  18.05  21.79  41.46
# 6571  14.50  16.42  18.88  29.58
# 6572  12.46  12.12  14.67  28.79
# 6573  11.58  11.38  12.08  22.08
#
# [6574 rows x 13 columns]

# %% [markdown]
# ### Step 5. Set the right dates as the index. Pay attention at the data type, it should be datetime64[ns].

# %%
data.Yr_Mo_Dy.dtype
# Out:
# dtype('O')

# %%
### date.time()으로 만든것은 object 타입이다
# Out:
# dtype('<M8[ns]')

# %%
# transform Yr_Mo_Dy it to date type datetime64
data["Yr_Mo_Dy"] = pd.to_datetime(data["Yr_Mo_Dy"])

# set 'Yr_Mo_Dy' as the index
data = data.set_index('Yr_Mo_Dy')

data.head()
# data.info()
# Out:
#               RPT    VAL    ROS    KIL    SHA   BIR    DUB    CLA    MUL  \
# Yr_Mo_Dy
# 1961-01-01  15.04  14.96  13.17   9.29    NaN  9.87  13.67  10.25  10.83
# 1961-01-02  14.71    NaN  10.83   6.50  12.62  7.67  11.50  10.04   9.79
# 1961-01-03  18.50  16.88  12.33  10.13  11.17  6.17  11.25    NaN   8.50
# 1961-01-04  10.58   6.63  11.75   4.58   4.54  2.88   8.63   1.79   5.83
# 1961-01-05  13.33  13.25  11.42   6.17  10.71  8.21  11.92   6.54  10.92
#
#               CLO    BEL    MAL
# Yr_Mo_Dy
# 1961-01-01  12.58  18.50  15.04
# 1961-01-02   9.67  17.54  13.83
# 1961-01-03   7.67  12.75  12.71
# 1961-01-04   5.88   5.46  10.88
# 1961-01-05  10.34  12.92  11.83

# %% [markdown]
# ### Step 6. Compute how many values are missing for each location over the entire record.
# #### They should be ignored in all calculations below.

# %%
for col in data.columns:
        msg='column: {:>10}\t Percent of NaN value: {:.2f}%'\
        .format(col,(t[col].isnull().sum()/len(data))*100)
        print(msg)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-65-f7c836bc8c89> in <module>
#       1 for col in data.columns:
#       2         msg='column: {:>10}\t Percent of NaN value: {:.2f}%'\
# ----> 3         .format(col,(t[col].isnull().sum()/len(data))*100)
#       4         print(msg)
#
# TypeError: 'Timestamp' object is not subscriptable

# %%
for col in data.columns:
    msg = f'colum:{col:>10}\t Percent of NaN values: {(data[col].isnull/len(data)):.2f}%'
    print(msg)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-63-4a70b482c852> in <module>
#       1 for col in data.columns:
# ----> 2     msg = f'colum:{col:>10}\t Percent of NaN values: {(data[col].isnull/len(data)):.2f}%'
#       3     print(msg)
#
# TypeError: unsupported operand type(s) for /: 'method' and 'int'

# %%
data.isnull().sum()
# Out:
# RPT    6
# VAL    3
# ROS    2
# KIL    5
# SHA    2
# BIR    0
# DUB    3
# CLA    2
# MUL    3
# CLO    1
# BEL    0
# MAL    4
# dtype: int64

# %%
len(data)
# Out:
# 6574

# %% [markdown]
# ### Step 7. Compute how many non-missing values there are in total.

# %%
data.notnull().sum()
# Out:
# RPT    6568
# VAL    6571
# ROS    6572
# KIL    6569
# SHA    6572
# BIR    6574
# DUB    6571
# CLA    6572
# MUL    6571
# CLO    6573
# BEL    6574
# MAL    6570
# dtype: int64

# %% [markdown]
# ### Step 8. Calculate the mean windspeeds of the windspeeds over all the locations and all the times.
# #### A single number for the entire dataset.

# %%
data.fillna(0).values.flatten().mean()
# Out:
# 10.223864592840483

# %% [markdown]
# ### Step 9. Create a DataFrame called loc_stats and calculate the min, max and mean windspeeds and standard deviations of the windspeeds at each location over all the days
#
# #### A different set of numbers for each location.

# %%
data.head()
# Out:
#               RPT    VAL    ROS    KIL    SHA   BIR    DUB    CLA    MUL  \
# Yr_Mo_Dy
# 1961-01-01  15.04  14.96  13.17   9.29    NaN  9.87  13.67  10.25  10.83
# 1961-01-02  14.71    NaN  10.83   6.50  12.62  7.67  11.50  10.04   9.79
# 1961-01-03  18.50  16.88  12.33  10.13  11.17  6.17  11.25    NaN   8.50
# 1961-01-04  10.58   6.63  11.75   4.58   4.54  2.88   8.63   1.79   5.83
# 1961-01-05  13.33  13.25  11.42   6.17  10.71  8.21  11.92   6.54  10.92
#
#               CLO    BEL    MAL
# Yr_Mo_Dy
# 1961-01-01  12.58  18.50  15.04
# 1961-01-02   9.67  17.54  13.83
# 1961-01-03   7.67  12.75  12.71
# 1961-01-04   5.88   5.46  10.88
# 1961-01-05  10.34  12.92  11.83

# %%
loc_stats['min'] = data

# %%
# Out:
# '<built-in function min>'

# %% [markdown]
# ### Step 10. Create a DataFrame called day_stats and calculate the min, max and mean windspeed and standard deviations of the windspeeds across all the locations at each day.
#
# #### A different set of numbers for each day.

# %% [markdown]
# ### Step 11. Find the average windspeed in January for each location.
# #### Treat January 1961 and January 1962 both as January.

# %% [markdown]
# ### Step 12. Downsample the record to a yearly frequency for each location.

# %% [markdown]
# ### Step 13. Downsample the record to a monthly frequency for each location.

# %% [markdown]
# ### Step 14. Downsample the record to a weekly frequency for each location.

# %% [markdown]
# ### Step 15. Calculate the min, max and mean windspeeds and standard deviations of the windspeeds across all locations for each week (assume that the first week starts on January 2 1961) for the first 52 weeks.
