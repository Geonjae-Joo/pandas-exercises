# %% [markdown]
# # Occupation

# %% [markdown]
# ### Introduction:
#
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user).

# %% [markdown]
# ### Step 3. Assign it to a variable called users.

# %%
users=pd.read_csv(r'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user',sep='|')
users
# Out:
#      user_id  age gender     occupation zip_code
# 0          1   24      M     technician    85711
# 1          2   53      F          other    94043
# 2          3   23      M         writer    32067
# 3          4   24      M     technician    43537
# 4          5   33      F          other    15213
# ..       ...  ...    ...            ...      ...
# 938      939   26      F        student    33319
# 939      940   32      M  administrator    02215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841
#
# [943 rows x 5 columns]

# %%
users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 943 entries, 0 to 942
# Data columns (total 5 columns):
# user_id       943 non-null int64
# age           943 non-null int64
# gender        943 non-null object
# occupation    943 non-null object
# zip_code      943 non-null object
# dtypes: int64(2), object(3)
# memory usage: 37.0+ KB

# %% [markdown]
# ### Step 4. Discover what is the mean age per occupation

# %%
users[['age','occupation']].groupby('occupation').describe()
# Out:
#                  age
#                count       mean        std   min    25%   50%    75%   max
# occupation
# administrator   79.0  38.746835  11.123397  21.0  30.00  37.0  48.00  70.0
# artist          28.0  31.392857   8.668116  19.0  25.00  30.0  39.00  48.0
# doctor           7.0  43.571429  12.501428  28.0  35.50  45.0  48.50  64.0
# educator        95.0  42.010526  10.413264  23.0  33.00  42.0  50.00  63.0
# engineer        67.0  36.388060  11.199236  22.0  28.00  36.0  43.00  70.0
# entertainment   18.0  29.222222  10.056052  15.0  23.00  25.0  33.00  50.0
# executive       32.0  38.718750  10.608075  22.0  31.00  38.5  46.00  69.0
# healthcare      16.0  41.562500  11.313524  22.0  30.50  44.5  49.25  62.0
# homemaker        7.0  32.571429  10.737119  20.0  24.50  32.0  38.50  50.0
# lawyer          12.0  36.750000  10.830303  21.0  28.75  34.0  47.75  53.0
# librarian       51.0  40.000000  11.023611  23.0  30.00  39.0  49.00  69.0
# ...

# %% [markdown]
# ### Step 5. Discover the Male ratio per occupation and sort it from the most to the least

# %%
users[['gender','occupation']].groupby('occupation').count()
# Out:
#                gender
# occupation
# administrator      79
# artist             28
# doctor              7
# educator           95
# engineer           67
# entertainment      18
# executive          32
# healthcare         16
# homemaker           7
# lawyer             12
# librarian          51
# marketing          26
# none                9
# other             105
# programmer         66
# retired            14
# salesman           12
# scientist          31
# student           196
# technician         27
# writer             45

# %%
users[users['gender']=='M'][['gender','occupation']].groupby('occupation').count()
# Out:
#                gender
# occupation
# administrator      43
# artist             15
# doctor              7
# educator           69
# engineer           65
# entertainment      16
# executive          29
# healthcare          5
# homemaker           1
# lawyer             10
# librarian          22
# marketing          16
# none                5
# other              69
# programmer         60
# retired            13
# salesman            9
# scientist          28
# student           136
# technician         26
# writer             26

# %%
round(100*(users[users['gender']=='M'][['gender','occupation']].groupby('occupation').count())/(users[['gender','occupation']].groupby('occupation').count()),2)
# Out:
#                gender
# occupation
# administrator   54.43
# artist          53.57
# doctor         100.00
# educator        72.63
# engineer        97.01
# entertainment   88.89
# executive       90.62
# healthcare      31.25
# homemaker       14.29
# lawyer          83.33
# librarian       43.14
# marketing       61.54
# none            55.56
# other           65.71
# programmer      90.91
# retired         92.86
# salesman        75.00
# scientist       90.32
# student         69.39
# technician      96.30
# writer          57.78

# %% [markdown]
# ### Step 6. For each occupation, calculate the minimum and maximum ages

# %%
que=users[['occupation','age']].groupby('occupation').describe()
que
# Out:
#                  age
#                count       mean        std   min    25%   50%    75%   max
# occupation
# administrator   79.0  38.746835  11.123397  21.0  30.00  37.0  48.00  70.0
# artist          28.0  31.392857   8.668116  19.0  25.00  30.0  39.00  48.0
# doctor           7.0  43.571429  12.501428  28.0  35.50  45.0  48.50  64.0
# educator        95.0  42.010526  10.413264  23.0  33.00  42.0  50.00  63.0
# engineer        67.0  36.388060  11.199236  22.0  28.00  36.0  43.00  70.0
# entertainment   18.0  29.222222  10.056052  15.0  23.00  25.0  33.00  50.0
# executive       32.0  38.718750  10.608075  22.0  31.00  38.5  46.00  69.0
# healthcare      16.0  41.562500  11.313524  22.0  30.50  44.5  49.25  62.0
# homemaker        7.0  32.571429  10.737119  20.0  24.50  32.0  38.50  50.0
# lawyer          12.0  36.750000  10.830303  21.0  28.75  34.0  47.75  53.0
# librarian       51.0  40.000000  11.023611  23.0  30.00  39.0  49.00  69.0
# ...

# %%
users.groupby('occupation').agg(['min', 'max','sum'])
# Out:
#               user_id             age           gender      \
#                   min  max    sum min max   sum    min max
# occupation
# administrator       7  940  34045  21  70  3061      F   M
# artist             23  920  12653  19  48   879      F   M
# doctor            138  935   3736  28  64   305      M   M
# educator           13  937  44356  23  63  3991      F   M
# engineer           25  934  30574  22  70  2438      F   M
# entertainment      16  926   7164  15  50   526      F   M
# executive           6  901  13514  22  69  1239      F   M
# healthcare         60  910   8023  22  62   665      F   M
# homemaker          20  898   3101  20  50   228      F   M
# lawyer             10  846   4309  21  53   441      F   M
# librarian          19  942  24816  23  69  2040      F   M
# marketing          46  881  11383  24  55   978      F   M
# none               57  756   3318  11  55   239      F   M
# other               2  936  56987  13  64  3625      F   M
# ...

# %% [markdown]
# ### Step 7. For each combination of occupation and gender, calculate the mean age

# %%
users[['occupation','gender','age']].groupby(['occupation','gender']).mean()
# Out:
#                             age
# occupation    gender
# administrator F       40.638889
#               M       37.162791
# artist        F       30.307692
#               M       32.333333
# doctor        M       43.571429
# educator      F       39.115385
#               M       43.101449
# engineer      F       29.500000
#               M       36.600000
# entertainment F       31.000000
#               M       29.000000
# executive     F       44.000000
#               M       38.172414
# healthcare    F       39.818182
#               M       45.400000
# homemaker     F       34.166667
#               M       23.000000
# lawyer        F       39.500000
#               M       36.200000
# librarian     F       40.000000
#               M       40.000000
# marketing     F       37.200000
#               M       37.875000
# none          F       36.500000
#               M       18.600000
# other         F       35.472222
#               M       34.028986
# ...

# %%
users.groupby(['occupation', 'gender'])['age'].mean()
# Out:
# occupation     gender
# administrator  F         40.638889
#                M         37.162791
# artist         F         30.307692
#                M         32.333333
# doctor         M         43.571429
# educator       F         39.115385
#                M         43.101449
# engineer       F         29.500000
#                M         36.600000
# entertainment  F         31.000000
#                M         29.000000
# executive      F         44.000000
#                M         38.172414
# healthcare     F         39.818182
#                M         45.400000
# homemaker      F         34.166667
#                M         23.000000
# lawyer         F         39.500000
#                M         36.200000
# librarian      F         40.000000
#                M         40.000000
# marketing      F         37.200000
#                M         37.875000
# none           F         36.500000
#                M         18.600000
# other          F         35.472222
# ...

# %% [markdown]
# ### Step 8.  For each occupation present the percentage of women and men

# %%
users[['occupation','gender','user_id']].groupby(['occupation','gender']).count()
# Out:
#                       user_id
# occupation    gender
# administrator F            36
#               M            43
# artist        F            13
#               M            15
# doctor        M             7
# educator      F            26
#               M            69
# engineer      F             2
#               M            65
# entertainment F             2
#               M            16
# executive     F             3
#               M            29
# healthcare    F            11
#               M             5
# homemaker     F             6
#               M             1
# lawyer        F             2
#               M            10
# librarian     F            29
#               M            22
# marketing     F            10
#               M            16
# none          F             4
#               M             5
# other         F            36
#               M            69
# programmer    F             6
#               M            60
# ...

# %%
users[['occupation','gender']].groupby('occupation').count()
# Out:
#                gender
# occupation
# administrator      79
# artist             28
# doctor              7
# educator           95
# engineer           67
# entertainment      18
# executive          32
# healthcare         16
# homemaker           7
# lawyer             12
# librarian          51
# marketing          26
# none                9
# other             105
# programmer         66
# retired            14
# salesman           12
# scientist          31
# student           196
# technician         27
# writer             45

# %%
# Out:
#                       gender  user_id
# occupation    gender
# administrator F          NaN      NaN
#               M          NaN      NaN
# artist        F          NaN      NaN
#               M          NaN      NaN
# doctor        M          NaN      NaN
# educator      F          NaN      NaN
#               M          NaN      NaN
# engineer      F          NaN      NaN
#               M          NaN      NaN
# entertainment F          NaN      NaN
#               M          NaN      NaN
# executive     F          NaN      NaN
#               M          NaN      NaN
# healthcare    F          NaN      NaN
#               M          NaN      NaN
# homemaker     F          NaN      NaN
#               M          NaN      NaN
# lawyer        F          NaN      NaN
#               M          NaN      NaN
# librarian     F          NaN      NaN
#               M          NaN      NaN
# marketing     F          NaN      NaN
#               M          NaN      NaN
# ...
